# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter

# %%
data = np.loadtxt('Expt 1 Data - Data.csv', delimiter=',',skiprows=1,dtype=str)

# %%
maleHeights = np.where(data[:,0] == 'Female')
maleHeight = data[maleHeights,1].astype(float)

blood = data[:,2]
print(blood)


# bins = np.arange(np.min(maleHeight[0]), np.max(maleHeight[0]),2)

bin = ['O', 'A', 'B', 'AB']
letter_count = Counter(blood)
df = pd.DataFrame.from_dict(letter_count, orient='index')

df.plot(kind='bar')
plt.xlabel('Blood Group')
plt.ylabel('Frequency')
plt.title('Blood Group Distribution')

# print(maleHeight[0])

# def var(a):
#     mean = np.mean(a)
#     vared = [(i - mean)**2 for i in a]
#     return np.sum(vared)/len(a)
print(np.mean(maleHeight[0]))  




# plt.hist(maleHeight[0], bins=bin)
# plt.xlabel('Height (cm) [Female]')
# plt.ylabel('Frequency')
# plt.show()
# Out:
# ['O' 'B' 'O' 'B' 'A' 'AB' 'B' 'O' 'B' 'B' 'O' 'B' 'AB' 'B' 'O' 'A' 'A' 'A'
#  'A' 'B' 'A' 'B' 'A' 'B' 'O' 'B' 'B' 'B' 'O' 'O' 'B' 'B' 'A' 'O' 'O' 'O'
#  'A' 'B' 'A' 'A' 'AB' 'AB' 'O' 'AB' 'B' 'B' 'A' 'AB' 'A' 'B' 'O' 'B' 'O'
#  'O' 'O' 'O' 'B' 'A' 'O' 'O' 'O' 'B' 'A' 'A' 'A' 'B' 'A' 'B' 'O' 'B' 'B'
#  'B' 'B' 'A' 'O' 'A' 'B' 'B' 'A' 'O' 'B' 'B' 'AB' 'B' 'B' 'A' 'A' 'O' 'O'
#  'B' 'A' 'AB' 'O' 'O' 'O' 'O' 'A']
# 160.34878048780487
